# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('world-happiness-report-2019.csv')
print(df)
# Out:
#              Country (region)  Ladder  SD of Ladder  Positive affect  \
# 0                     Finland       1             4             41.0
# 1                     Denmark       2            13             24.0
# 2                      Norway       3             8             16.0
# 3                     Iceland       4             9              3.0
# 4                 Netherlands       5             1             12.0
# 5                 Switzerland       6            11             44.0
# 6                      Sweden       7            18             34.0
# 7                 New Zealand       8            15             22.0
# 8                      Canada       9            23             18.0
# 9                     Austria      10            10             64.0
# 10                  Australia      11            26             47.0
# 11                 Costa Rica      12            62              4.0
# 12                     Israel      13            14            104.0
# ...

# %%
# Out:
#   File "<ipython-input-29-c8d7e4c8c77e>", line 1
#     df['Country (region)'].isin(['Denmark','Finland')
#                                                     ^
# SyntaxError: invalid syntax

# %%
plt.plot(df['Positive affect'], df['Country (region)'])
plt.show()

# %%
#single column, make one dimensional (true/false) - true for countries that I want to include and false for countries i dont want to include.

# %%
plt.boxplot(df['Country (region)'], df['Positive affect'] )
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-ab62eb514af7> in <module>
# ----> 1 plt.boxplot(df['Country (region)'], df['Positive affect'] )
#       2 plt.show()
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_xticks, autorange, zorder, data)
#    2496         whiskerprops=whiskerprops, manage_xticks=manage_xticks,
#    2497         autorange=autorange, zorder=zorder, **({"data": data} if data
# -> 2498         is not None else {}))
#    2499
#    2500
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
#df['Country (region)'].isin(['Denmark','Finland')

#country_mask = df['Country (region)'].isin(['Denmark','Finland'])

#df[country_mask]

# %%
plt.scatter(x=df['Freedom'], y=df['Corruption'])
plt.show()

# %%
import seaborn as sns
sns.set(style="ticks") 
#hue="Country (region)"
sns.pairplot(df[['Log of GDP\nper capita', 'Healthy life\nexpectancy', 'Positive affect']])

# %%
plt.scatter(x=df['Freedom'], y=df['Corruption'])
plt.show()

# %%
plt.scatter(x=df['Healthy life\nexpectancy'], y=df['Corruption'])
plt.ylabel('Corruption')
plt.xlabel('Health & Life Expectancy')
plt.title('Corruption and Health')
plt.show()

# %%
import pandas as pd

from pandas import DataFrame
df = pd.read_csv('world-happiness-report-2019.csv')


print (df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-711122b79393> in <module>
#       3 from pandas import DataFrame
#       4 df = pd.read_csv('world-happiness-report-2019.csv')
# ----> 5 surveys_df.iloc[0:3, 1:4]
#       6
#       7
#
# NameError: name 'surveys_df' is not defined

# %%
print

(
    df[['Country (region)', 'Positive affect', 'Corruption']]
)
# Out:
#              Country (region)  Positive affect  Corruption
# 0                     Finland             41.0         4.0
# 1                     Denmark             24.0         3.0
# 2                      Norway             16.0         8.0
# 3                     Iceland              3.0        45.0
# 4                 Netherlands             12.0        12.0
# 5                 Switzerland             44.0         7.0
# 6                      Sweden             34.0         6.0
# 7                 New Zealand             22.0         5.0
# 8                      Canada             18.0        11.0
# 9                     Austria             64.0        19.0
# 10                  Australia             47.0        13.0
# 11                 Costa Rica              4.0        58.0
# 12                     Israel            104.0        74.0
# 13                 Luxembourg             62.0         9.0
# 14             United Kingdom             52.0        15.0
# ...

# %%
print (
    df[df['Country (region)'] == 'Finland']

)
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
#
#    Healthy life\nexpectancy
# 0                      27.0

# %%
df[df['Country (region)'] == 'Finland']

plt.scatter(x=df['Healthy life\nexpectancy'], y=df['Corruption'])
plt.ylabel('Corruption')
plt.xlabel('Health & Life Expectancy')
plt.title('Corruption and Health')
plt.show()

# %%
import pandas as pd

from pandas import DataFrame
df = pd.read_csv('world-happiness-report-2019.csv')

df[:11]
# Out:
#    Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0           Finland       1             4             41.0             10.0
# 1           Denmark       2            13             24.0             26.0
# 2            Norway       3             8             16.0             29.0
# 3           Iceland       4             9              3.0              3.0
# 4       Netherlands       5             1             12.0             25.0
# 5       Switzerland       6            11             44.0             21.0
# 6            Sweden       7            18             34.0              8.0
# 7       New Zealand       8            15             22.0             12.0
# 8            Canada       9            23             18.0             49.0
# 9           Austria      10            10             64.0             24.0
# 10        Australia      11            26             47.0             37.0
#
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# a scatter plot comparing num_children and num_pets
df[9:10].plot(kind='scatter',x='Positive affect',y='Corruption',color='red')
plt.show()

# %%
df[:5].plot(kind='bar',x='Country (region)',y='Corruption')
df[:5]
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# ...

# %%
ax = plt.gca()

df[:5].plot(kind='line',x='Country (region)',y='Corruption',ax=ax)
df[:5].plot(kind='line',x='Country (region)',y='Healthy life\nexpectancy', color='red', ax=ax)
df[:5]
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df[:10].groupby('Freedom')['Healthy life\nexpectancy'].nunique().plot(kind='bar')
df[:10]

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df[:5].groupby(['Country (region)','Healthy life\nexpectancy']).size().unstack().plot(kind='bar',stacked=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline
happy_data = pd.read_csv('world-happiness-report-2019.csv')

# %%
print(happy_data.columns)
happy_data.head(11)
# Out:
# Index(['Country (region)', 'Ladder', 'SD of Ladder', 'Positive affect',
#        'Negative affect', 'Social support', 'Freedom', 'Corruption',
#        'Generosity', 'Log of GDP\nper capita', 'Healthy life\nexpectancy'],
#       dtype='object')
#    Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0           Finland       1             4             41.0             10.0
# 1           Denmark       2            13             24.0             26.0
# 2            Norway       3             8             16.0             29.0
# 3           Iceland       4             9              3.0              3.0
# 4       Netherlands       5             1             12.0             25.0
# 5       Switzerland       6            11             44.0             21.0
# 6            Sweden       7            18             34.0              8.0
# 7       New Zealand       8            15             22.0             12.0
# ...

# %%
import seaborn as sns

# %%
sns.set(style="ticks") 
#hue="Country (region)"
sns.pairplot(df[[ 'Healthy life\nexpectancy', 'Positive affect']])

# %%
sns.pairplot(car_data.loc[:,happy_data.dtypes == 'float64'])

# %%
sns.set(style="ticks") 
#hue="Country (region)"
sns.pairplot(df[[ 'Log of GDP\nper capita', 'Healthy life\nexpectancy']])

# %%
sns.set(style="ticks") 
#hue="Country (region)"
sns.pairplot(df[[ 'Log of GDP\nper capita', 'Social support']])

# %%
sns.set(style="ticks") 
#hue="Country (region)"
sns.pairplot(df[[ 'Social support', 'Healthy life\nexpectancy']])

# %%
corr = happy_data.loc[:,happy_data.dtypes == 'float64'].corr()
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap=sns.diverging_palette(220, 10, as_cmap=True))

# %%
sns.set(style="ticks") 
#hue="Country (region)"
sns.pairplot(df[[ 'Social support', 'Corruption']])

# %%
sns.set(style="ticks") 
#hue="Country (region)"
sns.pairplot(df[[ 'Healthy life\nexpectancy', 'Corruption']])

# %%
sns.set(style="ticks") 
#hue="Country (region)"
sns.pairplot(df[[ 'Freedom', 'Positive affect']])

# %%
df[:5].plot(kind='bar',x='Country (region)',y='Positive affect')
plt.ylim((0,140))

df[:5]
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# ...

# %%
df[151:].plot(kind='bar',x='Country (region)',y='Positive affect')
df[151:]
# Out:
#              Country (region)  Ladder  SD of Ladder  Positive affect  \
# 151                    Rwanda     152            63             54.0
# 152                  Tanzania     153           122             78.0
# 153               Afghanistan     154            25            152.0
# 154  Central African Republic     155           117            132.0
# 155               South Sudan     156           140            127.0
#
#      Negative affect  Social support  Freedom  Corruption  Generosity  \
# 151            102.0           144.0     21.0         2.0        90.0
# 152             50.0           131.0     78.0        34.0        49.0
# 153            133.0           151.0    155.0       136.0       137.0
# 154            153.0           155.0    133.0       122.0       113.0
# 155            152.0           148.0    154.0        61.0        85.0
#
#      Log of GDP\nper capita  Healthy life\nexpectancy
# 151                   132.0                     103.0
# ...

# %%
df[:5].plot(kind='bar',x='Country (region)',y='Social support')
plt.ylim((0,160))
df[:5]
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# ...

# %%
df[151:].plot(kind='bar',x='Country (region)',y='Social support')
df[151:]
# Out:
#              Country (region)  Ladder  SD of Ladder  Positive affect  \
# 151                    Rwanda     152            63             54.0
# 152                  Tanzania     153           122             78.0
# 153               Afghanistan     154            25            152.0
# 154  Central African Republic     155           117            132.0
# 155               South Sudan     156           140            127.0
#
#      Negative affect  Social support  Freedom  Corruption  Generosity  \
# 151            102.0           144.0     21.0         2.0        90.0
# 152             50.0           131.0     78.0        34.0        49.0
# 153            133.0           151.0    155.0       136.0       137.0
# 154            153.0           155.0    133.0       122.0       113.0
# 155            152.0           148.0    154.0        61.0        85.0
#
#      Log of GDP\nper capita  Healthy life\nexpectancy
# 151                   132.0                     103.0
# ...

# %%
df[151:].plot(kind='bar',x='Country (region)',y='Negative affect')
df[151:]
# Out:
#              Country (region)  Ladder  SD of Ladder  Positive affect  \
# 151                    Rwanda     152            63             54.0
# 152                  Tanzania     153           122             78.0
# 153               Afghanistan     154            25            152.0
# 154  Central African Republic     155           117            132.0
# 155               South Sudan     156           140            127.0
#
#      Negative affect  Social support  Freedom  Corruption  Generosity  \
# 151            102.0           144.0     21.0         2.0        90.0
# 152             50.0           131.0     78.0        34.0        49.0
# 153            133.0           151.0    155.0       136.0       137.0
# 154            153.0           155.0    133.0       122.0       113.0
# 155            152.0           148.0    154.0        61.0        85.0
#
#      Log of GDP\nper capita  Healthy life\nexpectancy
# 151                   132.0                     103.0
# ...

# %%
df[:5].plot(kind='bar',x='Country (region)',y='Negative affect')
plt.ylim((0,160))
df[:5]
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# ...

# %%
df[:5].plot(kind='bar',x='Country (region)',y='Healthy life\nexpectancy')
plt.ylim((0,140))

df[:5]
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# ...

# %%
df[151:].plot(kind='bar',x='Country (region)',y='Healthy life\nexpectancy')
df[151:]
# Out:
#              Country (region)  Ladder  SD of Ladder  Positive affect  \
# 151                    Rwanda     152            63             54.0
# 152                  Tanzania     153           122             78.0
# 153               Afghanistan     154            25            152.0
# 154  Central African Republic     155           117            132.0
# 155               South Sudan     156           140            127.0
#
#      Negative affect  Social support  Freedom  Corruption  Generosity  \
# 151            102.0           144.0     21.0         2.0        90.0
# 152             50.0           131.0     78.0        34.0        49.0
# 153            133.0           151.0    155.0       136.0       137.0
# 154            153.0           155.0    133.0       122.0       113.0
# 155            152.0           148.0    154.0        61.0        85.0
#
#      Log of GDP\nper capita  Healthy life\nexpectancy
# 151                   132.0                     103.0
# ...

# %%
df[151:].plot(kind='bar',x='Country (region)',y='Generosity')
plt.ylim((0,140))

df[151:]
# Out:
#              Country (region)  Ladder  SD of Ladder  Positive affect  \
# 151                    Rwanda     152            63             54.0
# 152                  Tanzania     153           122             78.0
# 153               Afghanistan     154            25            152.0
# 154  Central African Republic     155           117            132.0
# 155               South Sudan     156           140            127.0
#
#      Negative affect  Social support  Freedom  Corruption  Generosity  \
# 151            102.0           144.0     21.0         2.0        90.0
# 152             50.0           131.0     78.0        34.0        49.0
# 153            133.0           151.0    155.0       136.0       137.0
# 154            153.0           155.0    133.0       122.0       113.0
# 155            152.0           148.0    154.0        61.0        85.0
#
#      Log of GDP\nper capita  Healthy life\nexpectancy
# 151                   132.0                     103.0
# ...

# %%
df[:5].plot(kind='bar',x='Country (region)',y='Generosity')
plt.ylim((0,140))

df[:5]
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# ...
