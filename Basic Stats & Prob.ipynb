# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Making a standard normally distributed variable with 1000 observations, a mean of 0, and 
# a standard deviation of 1, and putting it in a data frame.
mean = 0 
sd = 1
n = 1000

df = pd.DataFrame({'rand': np.random.normal(mean, sd, n)})

# Plotting the variables in the data frame (here, just the variable "rand") as a histogram.
df.hist()
# Inline printing the histogram
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Making two variables.
rand1 = np.random.normal(50, 300, 1000)
rand2 = np.random.poisson(1, 1000)

# Sorting the values in ascending order.
rand1.sort()
rand2.sort()

# Making a standard normally distributed variable with 1000 observations,
# a mean of 0, and standard deviation of 1 that we will use as our “comparison.”
norm = np.random.normal(0, 1, 1000)

# Sorting the values in ascending order.
norm.sort()

# %%
# Plotting the variable rand1 against norm in qqplots.
plt.plot(norm, rand1, "o") 
plt.show()

# %%
# Plotting the variable rand2 against norm in qqplots.
plt.plot(norm, rand2, "o") 
plt.show()

# %%
#Plot a histogram for rand1.
plt.hist(rand1, bins=20, color='c')

# Add a vertical line at the mean.
plt.axvline(rand1.mean(), color='b', linestyle='solid', linewidth=2)

# Add a vertical line at one standard deviation above the mean.
plt.axvline(rand1.mean() + rand1.std(), color='b', linestyle='dashed', linewidth=2)

# Add a vertical line at one standard deviation below the mean.
plt.axvline(rand1.mean()-rand1.std(), color='b', linestyle='dashed', linewidth=2) 

# Print the histogram.
plt.show()

# %%
#Plot a histogram for rand1.
plt.hist(rand1, bins=20, color='c')

# Add a vertical line at the mean.
plt.axvline(rand1.mean(), color='b', linestyle='solid', linewidth=2)

# Add a vertical line at one standard deviation above the mean.
plt.axvline(rand1.mean() + rand1.std(), color='b', linestyle='dashed', linewidth=2)

# Add a vertical line at one standard deviation below the mean.
plt.axvline(rand1.mean()-rand1.std(), color='b', linestyle='dashed', linewidth=2) 

# Print the histogram.
plt.show()

# %%
# Generate a bernoulli distribution with p =0.5.
bernoulli= np.random.binomial(1, .5, 1000)

#Plot a histogram.
plt.hist(bernoulli)

# Print the histogram
plt.show()

# %%
# Generate a binomial distribution with n=20 and p=0.5.
binomial = np.random.binomial(20, 0.5, 1000)

# Plot a histogram.
plt.hist(binomial)

# Print the histogram.
plt.show()

# %%
# Generate a Poisson distribution with lambda = 3
poisson = np.random.poisson(3, 1000)

# Plot a histogram.
plt.hist(poisson)

# Print the histogram.
plt.show()

# %%
# Creating a data frame to hold the simulated ecommerce data, and populating it with a
# normally distributed variable with mean 75 and standard deviation 25.

ecommerce = pd.DataFrame()
ecommerce['spending'] = np.random.normal(75, 25, 1000)

# Plot a histogram.
plt.hist(ecommerce['spending'])
plt.show()

# %%
# Adding a variable with counts of number of times visiting the site.
ecommerce['visit_count'] = np.random.randint(0, 5, 1000)

# Selecting only the cases where the visit count is greater than two and plotting those.
plt.hist(ecommerce[ecommerce['visit_count'] > 2]['spending'])
plt.show()

# %%
ireneplot = np.random.ireneplot (1, .5, 1000)
#Plot a histogram.
plt.hist(ireneplot)

# Print the histogram
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-6a0229d01e98> in <module>
# ----> 1 ireneplot = np.random.ireneplot (1, .5, 1000)
#       2 #Plot a histogram.
#       3 plt.hist(ireneplot)
#       4
#       5 # Print the histogram
#
# AttributeError: module 'numpy.random' has no attribute 'ireneplot'

# %%
plt.axvline(ireneplot['spending'].mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline(ireneplot['spending'].mean() + rand1.std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline(ireneplot['spending'].mean() -rand1.std(), color='b', linestyle='dashed', linewidth=2) 
ireneplot['spending'].mean()

# Plot a histogram.
plt.hist(ireneplot['spending'])
plt.show()

#could use some help with this. Not sure

# %%
ireneplot = pd.DataFrame()
ireneplot['spending'] = np.random.normal(1, 200, 100)

ireneplot_mean = ireneplot['spending'].mean()
ireneplot_std = ireneplot['spending'].std()

plt.axvline(ireneplot_mean, 'b-', linewidth=2)
plt.axvline(ireneplot_mean + ireneplot_std, 'b--', linewidth=2)
plt.axvline(ireneplot_mean - ireneplot_std, 'b--', linewidth=2)

# Plot a histogram.
plt.hist(ireneplot['spending'])
plt.show()

#could use some help with this. Not sure
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-4ce38e3c5eaa> in <module>
#       5 ireneplot_std = ireneplot['spending'].std()
#       6
# ----> 7 plt.axvline(ireneplot_mean, 'b-', linewidth=2)
#       8 plt.axvline(ireneplot_mean + ireneplot_std, 'b--', linewidth=2)
#       9 plt.axvline(ireneplot_mean - ireneplot_std, 'b--', linewidth=2)
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in axvline(x, ymin, ymax, **kwargs)
#    2441 @docstring.copy_dedent(Axes.axvline)
#    2442 def axvline(x=0, ymin=0, ymax=1, **kwargs):
# -> 2443     return gca().axvline(x=x, ymin=ymin, ymax=ymax, **kwargs)
#    2444
#    2445
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in axvline(self, x, ymin, ymax, **kwargs)
#     877         trans = self.get_xaxis_transform(which='grid')
#     878         l = mlines.Line2D([x, x], [ymin, ymax], transform=trans, **kwargs)
# --> 879         self.add_line(l)
#     880         self.autoscale_view(scalex=scalex, scaley=False)
#     881         return l
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in add_line(self, line)
#    1893             line.set_clip_path(self.patch)
#    1894
# -> 1895         self._update_line_limits(line)
#    1896         if not line.get_label():
#    1897             line.set_label('_line%d' % len(self.lines))
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _update_line_limits(self, line)
#    1915         Figures out the data limit of the given line, updating self.dataLim.
#    1916         """
# -> 1917         path = line.get_path()
#    1918         if path.vertices.size == 0:
#    1919             return
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/lines.py in get_path(self)
#     943         """
#     944         if self._invalidy or self._invalidx:
# --> 945             self.recache()
#     946         return self._path
#     947
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/lines.py in recache(self, always)
#     642             x = self._x
#     643         if always or self._invalidy:
# --> 644             yconv = self.convert_yunits(self._yorig)
#     645             y = _to_unmasked_float_array(yconv).ravel()
#     646         else:
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in convert_yunits(self, y)
#     193         if ax is None or ax.yaxis is None:
#     194             return y
# --> 195         return ax.yaxis.convert_units(y)
#     196
#     197     @property
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in convert_units(self, x)
#    1528             return x
#    1529
# -> 1530         ret = self.converter.convert(x, self.units, self)
#    1531         return ret
#    1532
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/category.py in convert(value, unit, axis)
#      51
#      52         # force an update so it also does type checking
# ---> 53         unit.update(values)
#      54
#      55         str2idx = np.vectorize(unit._mapping.__getitem__,
#
# AttributeError: 'NoneType' object has no attribute 'update'
